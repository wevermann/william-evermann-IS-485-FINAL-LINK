# %%
#check the versions of libraries

#
import sys
print('python:{}'. format(sys.version))
#
import scipy
print('scipy:{}'. format(scipy.__version__))
#
import numpy
print('numpy:{}'. format(numpy.__version__))
#
import matplotlib
print('matplotlib:{}'. format(matplotlib.__version__))
#
import pandas
print('pandas:{}'. format(pandas.__version__))
#
import sklearn
print('sklearn:{}'. format(sklearn.__version__))
# Out:
# python:3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)]
# scipy:1.1.0
# numpy:1.15.1
# matplotlib:2.2.3
# pandas:0.23.4
# sklearn:0.19.2

# %% [markdown]
# <p>
#     William Evermann<br/>
#     IS 485<br/>
#     Final Project<br/>
# </p>
#
# # Number of Documented Sexual Assault Cases from 2002-2018
#
# <p>
#     Data Collection
# <br/>
# My data was collected from the Washoe County District Attorney’s Office, with all personal information redacted. The data consists of sexual assaults victims requesting examinations and/or additional services through local Victims of Crime programs. There are more than 5200 lines of data spanning 2002 through September of 2018.
# </p>
# <br>
# <p>
#   Cleaning<br/>
# I confirmed that the date data was divided into separate columns to allow ease of manipulation. The program was able to differentiate the month, day, and year columns.
#
# </p>
# <br>
# <p>
# Hypothesis test<br/>
# My hypothesis is that there will be an increase in the number of documented assaults as more people feel more comfortable reporting the crime and seeking accountability though the criminal justice system due to the recent “Me Too” movement. This trend will continue until we reach the singularity moment, where the number of assaults will take one of two paths: (1) they will start to decrease as this current push loses momentum, or (2) the number of reports will plateau.
# </p>
# <br>
# <p>
# Machine leaning implementation<br/>
# Cross value analysis returned unknown errors. After trying six algorithms from class notes, the error persisted.
# </p>
# <br>
#
# <p>
# Conclusion<br/>
# I was able to determine that the summer months experience a slight increase in the number of reports compared with the rest of the year. In recent years, there were more records as more people were coming forward to report sexual assaults. However, I experienced an ongoing error. After attempting multiple attempts to rectify the errors, I have not yet found a solution. I do believe with more time I could get passed the error and provide more meaningful analysis. I would also like take my data one step further to determine if there is a specific month or week that is worse out of each year or month.
# Some of the limitations of my data include<br/>
# •	The data points are only based on incidents that were reported. This excludes delayed reports made to law enforcement months or years later. This also excluded other sex crime crimes categories, referring only to sexual assault and attempted sexual assault as defined by NRS 217.<br/>
# •	The 2018 year only goes through September
# </p>

# %%
# Load libraries
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from pandas import DataFrame
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

#Load Data
ReadExcel = pd.read_excel(r'C:\Users\Will\Desktop\SA-Database-WKJE.xlsx')
df = DataFrame(ReadExcel, ) 

#Verifing Data Read in Properly
#print(df)

#Used to test groupby stats
print(df.groupby(['Year', 'Month']).size())
df['Year'] = pd.to_numeric(df['Year'])
df['Day'] = pd.to_numeric(df['Day'])
df['Month'] = pd.to_numeric(df['Month'])

#Split Validation Data
array = df.values
X = array[:,0:2]
Y = array[:,2]
validation_size = 0.30
seed = 42
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)


knn = KNeighborsClassifier(n_neighbors = 6)

knn = knn.fit(X_train, Y_train)

Y_predictor = knn.predict(X_test)

print(results(Y_test, Y_prediction))
# Out:
# Year  Month
# 2002  1        27
#       2        24
#       3        34
#       4        36
#       5        34
#       6        32
#       7        35
#       8        43
#       9        23
#       10       21
#       11       23
#       12       16
# 2003  1        32
#       2        32
#       3        23
#       4        16
#       5        44
#       6        35
#       7        39
#       8        32
#       9        33
#       10       18
#       11       17
#       12       28
# 2004  1        29
#       2        25
#       3        28
#       4        35
#       5        34
#       6        28
#                ..
# 2016  4        34
#       5        23
#       6        28
#       7        27
#       8        26
#       9        31
#       10       30
#       11       31
#       12       27
# 2017  1        24
#       2        25
#       3        24
#       4        33
#       5        27
#       6        27
#       7        28
#       8        33
#       9        25
# ...
